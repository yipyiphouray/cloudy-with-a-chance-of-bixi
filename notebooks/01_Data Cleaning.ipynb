# %%
#~ importing libraries

import pandas as pd, numpy as np, requests, os

from meteostat import Hourly, Point
from datetime import datetime

from pathlib import Path

#~ setting up project directories 

PROJECT_ROOT = Path.cwd().resolve().parents[0]

DATA_DIR = PROJECT_ROOT / 'data' 

RAW_DIR = DATA_DIR / 'raw'

PROCESSED_DIR = DATA_DIR / 'processed'

# %% [markdown]
# # Generating the Dataset

# %%
#~ fetching hourly weather data from meteostat for Montreal City from 2023-2024
montreal = Point(45.5017, -73.5673)

weather_df = Hourly(
    montreal,
        start=datetime(2023, 1, 1),
            end=datetime(2024, 12, 31)
            ).fetch()

# %%
#~ fetching BIXI's station information

URL = "https://gbfs.velobixi.com/gbfs/2-2/en/station_information.json"

raw = requests.get(URL, timeout=30).json()

stations_status_df = pd.json_normalize(raw["data"]["stations"])

keep_stations_columns = [
    "station_id", "name", "lat", "lon", "capacity"
]
stations_status_df = stations_status_df[[c for c in keep_stations_columns if c in stations_status_df.columns]]

# %%
bixi_trip_2024_df = pd.read_csv(RAW_DIR/'BIXI_Trip_2024.csv')


bixi_trip_2023_df = pd.read_csv(RAW_DIR/'BIXI_Trip_2023.csv')


bixi_trip_df = pd.concat([bixi_trip_2023_df,bixi_trip_2024_df], ignore_index=True)

# %% [markdown]
# # Data Cleaning

# %%
'''function for quick description of dataframe'''
def explore_data(df):
    print("Dataframe Shape:", df.shape)
    print("\nDataframe Info:")
    print(df.info())
    print("\nMissing Values:\n", df.isnull().sum())
    print("\nStatistical Summary:\n", df.describe())
    print("\nFirst 5 Rows:\n", df.head())

# %% [markdown]
# ## BIXI Station Information Dataset

# %%
explore_data(stations_status_df)
# Out:
# Dataframe Shape: (239, 5)
#
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   station_id  239 non-null    object
#  1   name        239 non-null    object
#  2   lat         239 non-null    float64
#  3   lon         239 non-null    float64
#  4   capacity    239 non-null    int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 9.5+ KB
# None
#
# Missing Values:
#  station_id    0
# name          0
# lat           0
# lon           0
# capacity      0
# dtype: int64
#
# Statistical Summary:
#                lat         lon    capacity
# count  239.000000  239.000000  239.000000
# mean    45.516834  -73.579330   23.719665
# std      0.033080    0.027722    9.367882
# min     45.446505  -73.667162   11.000000
# 25%     45.496849  -73.597764   19.000000
# 50%     45.515868  -73.573338   21.000000
# 75%     45.537172  -73.562035   27.000000
# max     45.630686  -73.494847   81.000000
#
# First 5 Rows:
#    station_id                                          name        lat  \
# 0          3                               Clark / Ontario  45.510588
# 1         15  Métro Berri-UQAM (St-Denis / de Maisonneuve)  45.514252
# 2         17                  Marché St-Jacques (Atateken)  45.520666
# 3         19          Métro Sherbrooke (de Rigaud / Berri)  45.518143
# 4         24                       Notre-Dame / St-Gabriel  45.507118
#
#          lon  capacity
# 0 -73.566846        19
# 1 -73.561502        15
# 2 -73.563915        27
# 3 -73.568004        27
# 4 -73.555049        11

# %%
#~ sorting the dataframe by station name

stations_status_df = stations_status_df.sort_values(by='name')

stations_status_df['name'].unique().tolist()
# Out:
# ['1ere avenue / St-Zotique',
#  '20e avenue / de Bellechasse',
#  '3e avenue / Bannantyne',
#  '3e avenue / Wellington',
#  '6e Avenue / Bélanger',
#  '9e avenue / Masson',
#  'Argyle / Bannantyne',
#  'Atwater / Sherbrooke',
#  'Aylwin / Ontario',
#  'BIXI K5',
#  'Beaubien / 8e avenue',
#  'Bennett / Ste-Catherine',
#  'Benny / Sherbrooke',
#  'Bernard / Jeanne-Mance',
#  'Berri / Rachel',
#  'Beurling / Godin',
#  'Bibliothèque et Complexe aquatique Rosemont (8e avenue / Rosemont)',
#  'Boileau / Lacordaire',
#  'Bourbonnière / du Mont-Royal',
#  'Bourret / Victoria',
#  'Boyer / Jean-Talon',
#  'CHSLD Joseph-François-Perrault (St-Michel / Everett)',
#  'CHSLD Robert Cliche (de Bellechasse / 16e avenue)',
#  'CHU Ste-Justine (de la Côte Ste-Catherine / Hudson)',
#  'Calixa-Lavallée / Rachel',
#  'Calixa-Lavallée / Rachel (ouest)',
#  'Campus MIL (Outremont / Thérèse-Lavoie Roux)',
#  'Cartier / Marie-Anne',
#  'Cathcart / McGill College',
#  'Chabanel / du Parc',
#  'Christophe-Colomb / Beaubien',
#  'Clark / Ontario',
#  "Clark / de l'Arcade",
#  'Collège Ahuntsic (St-Hubert / Émile-Journault)',
#  'Collège André-Grasset (Crémazie / Christophe-Colomb)',
#  'Collège de Maisonneuve (Sherbrooke / Bourbonnière)',
#  'Collège de Rosemont (Beaubien / 15e avenue)',
#  'Complexe Desjardins (St-Urbain / René-Lévesque)',
#  "Cégep du Vieux-Montréal (Ontario / de l'Hôtel-de-Ville)",
#  'Dorion / Ontario',
#  'Duchesneau / de Marseille',
#  'Duke / Nazareth',
#  'Duluth / St-Denis',
#  "Duluth / de l'Esplanade",
#  'Durocher / Bernard',
#  'Elmwood / Mc Dougall',
#  'Fabrik8 (Waverly / Jean-Talon)',
#  'Fortune / Wellington',
#  'Frontenac / Ste-Catherine',
#  'Fullum / Marie-Anne',
#  'Garnier / Beaubien',
#  'Garnier / du Mont-Royal',
#  "Gaétan-Laberge / de l'Église",
#  'Georges-Vanier / Notre-Dame',
#  'Gordon / Wellington',
#  'Grand Boulevard / de Terrebonne',
#  'Grey / Sherbrooke',
#  'HEC (Decelles / Jean-Brillant)',
#  'Hamilton / Jolicoeur',
#  'Hôpital Notre-Dame (Alexandre-DeSève)',
#  'Hôpital général juif (de la Côte-Ste-Catherine / Légaré)',
#  'IUSMM (Georges-Villeneuve)',
#  'Jeanne-Mance / René-Lévesque',
#  'Jeanne-Mance / Sherbrooke',
#  'LaSalle / Godin',
#  'Lajeunesse / Villeray',
#  "Lanouette / de l'Église",
#  'Laurier / St-Denis',
#  'Laurier / de Brébeuf',
#  'Marché Atwater',
#  'Marché Jean-Talon (Casgrain / Shamrock)',
#  'Marché Maisonneuve (Ontario / Morgan)',
#  'Marché St-Jacques (Atateken)',
#  'Marquette / des Carrières',
#  'Marquette / du Mont-Royal (sud)',
#  'Masson / Molson',
#  "McGill / Place d'Youville",
#  'McTavish / Sherbrooke',
#  'Melrose / de Verdun',
#  'Melville / de Maisonneuve',
#  'Messier / Rachel',
#  'Messier / St-Joseph',
#  'Metcalfe / Ste-Catherine',
#  'Milton / St-Laurent',
#  'Molson / William-Tremblay',
#  "Métro / REM Édouard-Montpetit (Vincent-d'Indy)",
#  "Métro Acadie (de l'Acadie / Beaumont)",
#  'Métro Angrignon (Lamont / des Trinitaires)',
#  'Métro Assomption (Chauveau / Assomption)',
#  'Métro Atwater (Atwater / Ste-Catherine )',
#  'Métro Beaubien (de St-Vallier / Beaubien)',
#  'Métro Berri-UQAM (St-Denis / de Maisonneuve)',
#  'Métro Champ-de-Mars (Viger / Sanguinet)',
#  'Métro Crémazie (Crémazie / Lajeunesse)',
#  'Métro Fabre (Fabre / Jean-Talon)',
#  'Métro Fabre (Papineau / Jean-Talon)',
#  'Métro Frontenac (Ontario / du Havre)',
#  'Métro Henri-Bourassa (Henri-Bourassa / Millen)',
#  'Métro Honoré-Beaugrand (Sherbrooke / Honoré-Beaugrand)',
#  'Métro Jolicoeur (de Sève / Drake)',
#  'Métro Langelier (Langelier / Sherbrooke)',
#  'Métro Laurier (Berri / St-Joseph)',
#  'Métro Lionel-Groulx (St-Jacques / Atwater)',
#  "Métro Lucien-L'Allier (Lucien l'Allier / Argyle)",
#  'Métro Mont-Royal (Place Gérald-Godin)',
#  'Métro Papineau (Dorion / De Maisonneuve)',
#  'Métro Parc  (Hutchison / Ogilvy)',
#  'Métro Peel (de Maisonneuve / Stanley)',
#  'Métro Pie-IX (Pierre-de-Coubertin / Desjardins)',
#  "Métro Place-d'Armes (St-Urbain / Viger)",
#  'Métro Préfontaine (Moreau / Hochelaga)',
#  'Métro Radisson (Sherbrooke / des Groseilliers)',
#  'Métro Rosemont (de St-Vallier / Rosemont)',
#  'Métro Sauvé (Berri / Sauvé)',
#  'Métro Sherbrooke (de Rigaud / Berri)',
#  'Métro Square-Victoria-OACI (St-Jacques)',
#  'Métro St-Laurent (de Maisonneuve / St-Laurent)',
#  'Métro Université de Montréal (Édouard-Montpetit / Louis-Collin)',
#  'Métro Vendôme (de Maisonneuve / Grey)',
#  'Métro Verdun (Willibrord / de Verdun)',
#  'Métro Viau (Pierre-de-Coubertin / Viau)',
#  'Métro Villa-Maria (de Monkland / Décarie)',
#  "Métro de l'Église (Ross / de l'Église)",
#  'Notre-Dame / St-Gabriel',
#  'Notre-Dame / St-Martin',
#  'Omer-Lavallée / du Midway',
#  'Ontario / Poupart',
#  'Ontario / Ville-Marie',
#  'Ottawa / du Séminaire',
#  'Parc André-Lavallée (Laurier)',
#  'Parc Beaubien Outremont (Stuart / St-Viateur)',
#  'Parc Benny (Benny / de Monkland)',
#  'Parc Gabriel-Sagard (Jean-Talon / Sagard)',
#  'Parc Georges St-Pierre (Oxford / Upper Lachine)',
#  'Parc Hector-Toe-Blake (du Sussex / René-Lévesque)',
#  'Parc Hilda-Ramacière (de Bullion / Prince-Arthur)',
#  'Parc Ignace-Bourget (de Montmagny / Newman)',
#  'Parc Jeanne-Mance (monument sir George-Étienne-Cartier)',
#  'Parc Labelle (LaSalle / Henri-Duhamel)',
#  'Parc MacDonald (Clanranald / Isabella)',
#  "Parc Molson (d'Iberville / Beaubien)",
#  'Parc Pratt (Dunlop / Van Horne)',
#  'Parc St-Gabriel (Grand Trunk / Ropery)',
#  'Parc St-Roch (Ball / Durocher)',
#  'Parc Villeray (Jarry / Christophe-Colomb)',
#  'Parc de Montréal-Est (Notre-Dame / David)',
#  'Parc de Turin (de Lanaudière / Jean-Talon)',
#  "Parc de l'Hôtel-de-Ville (Ste-Julie / Laurendeau)",
#  'Parc de la Confédération (Fielding / West Hill)',
#  'Parc des Gorilles (Beaubien / St-Urbain)',
#  'Parc du Mont-Royal (Remembrance)',
#  'Parc du Père-Marquette (de Bellechasse / de Lanaudière)',
#  'Parthenais / du Mont-Royal',
#  'Peel / Notre-Dame',
#  'Pierre-de-Coubertin / Aird',
#  'Place Valois (Valois / Ontario)',
#  'Place Ville-Marie (Robert-Bourassa / René-Lévesque)',
#  'Place de la Paix (St-Laurent)',
#  'Place des Montréalaises (St-Antoine)',
#  'Place du Canada (Peel / des Canadiens-de-Montréal)',
#  'Place Émilie-Gamelin (St-Hubert / de Maisonneuve)',
#  'Prince-Arthur / St-Urbain',
#  'REM McGill (de Maisonneuve / Mansfield)',
#  'Rachel / de Brébeuf',
#  'Regina / de Verdun',
#  'René-Lévesque / Papineau',
#  'René-Lévesque / de Lorimier',
#  'Rielle / Wellington',
#  'Robert-Bourassa / St-Maurice',
#  'Roy / Saint-Laurent',
#  'Roy / St-André',
#  'Sherbrooke / Grand Boulevard',
#  "Sherbrooke / Jeanne-d'Arc",
#  'Smith / Peel',
#  'Square Viger (Berri)',
#  'Square-Victoria (Viger / du Square-Victoria)',
#  'St-Antoine / Jean-Paul Riopelle',
#  'St-Antoine / Robert-Bourassa',
#  'St-Antoine / de la Montagne',
#  'St-Grégoire / Christophe-Colomb',
#  'St-Hubert / de Maisonneuve',
#  'St-Patrick / Thomas-Keefer',
#  'St-Rémi / Ste-Émilie',
#  'St-Urbain / Laurier',
#  'St-Viateur / Casgrain',
#  'Stanley / René-Lévesque',
#  'Ste-Catherine / Bishop',
#  'Ste-Catherine / St-Clément',
#  'Ste-Catherine / Union',
#  'Ste-Claire / Baldwin',
#  'Ste-Émilie / Sir-Georges-Etienne-Cartier',
#  'Viger / Chenneville',
#  'Villeray / de Normanville',
#  'Wellington / Queen',
#  'William / Robert-Bourassa',
#  'Wilson / Sherbrooke',
#  'de Bordeaux / Gilford',
#  'de Courcelle / Acorn',
#  'de Gaspé / Marmier',
#  'de Kent / Hudson',
#  'de Maisonneuve / Aylmer (est)',
#  'de Maisonneuve / Aylmer (ouest)',
#  'de Maisonneuve / Fullum',
#  'de Maisonneuve / Greene',
#  'de Maisonneuve / Mackay',
#  'de Maisonneuve / Mansfield (nord)',
#  'de Maisonneuve / Mansfield (sud)',
#  'de Maisonneuve / de Bleury',
#  'de Marseille / de la Pépinière',
#  'de Monkland / Girouard',
#  'de Normanville / Beaubien',
#  "de l'Esplanade / Fairmount",
#  "de l'Hôtel-de-Ville / Rachel",
#  "de l'Inspecteur / Notre-Dame",
#  'de la Commune / Berri',
#  'de la Commune / McGill',
#  'de la Commune / Nazareth',
#  'de la Commune / Place Jacques-Cartier',
#  'de la Commune / St-Sulpice',
#  'de la Côte-Ste-Catherine / Davaar',
#  'de la Côte-Ste-Catherine / Decelles',
#  'de la Montagne / Notre-Dame',
#  'de la Porte de Québec / St-André',
#  'des Barges / des Bassins',
#  'des Ormeaux / de Grosbois',
#  'des Pins / St-Laurent',
#  'des Vraquiers / Ottawa',
#  'des Érables / Laurier',
#  'des Érables / Rachel',
#  'du Havre / Hochelaga',
#  'du Mont-Royal / Christophe-Colomb',
#  'du Mont-Royal / Clark',
#  'du Mont-Royal / St-André',
#  'du Mont-Royal / de Brébeuf',
#  'du Parc-La Fontaine / Rachel',
#  'du Séminaire / de la Montagne',
#  'Édouard-Montpetit / de Stirling',
#  'Émile-Duployé / Rachel',
#  'Émile-Duployé / Sherbrooke']

# %% [markdown]
# ## Weather Dataset from MeteoStat API

# %% [markdown]
# Link for more info about meteostat:
# https://dev.meteostat.net/python/hourly.html#example

# %%
explore_data(weather_df)
# Out:
# Dataframe Shape: (17521, 11)
#
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17521 entries, 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# Freq: h
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   temp    17521 non-null  Float64
#  1   dwpt    17521 non-null  Float64
#  2   rhum    17521 non-null  Float64
#  3   prcp    17521 non-null  Float64
#  4   snow    0 non-null      Float64
#  5   wdir    17521 non-null  Float64
#  6   wspd    17521 non-null  Float64
#  7   wpgt    0 non-null      Float64
#  8   pres    17521 non-null  Float64
#  9   tsun    0 non-null      Float64
#  10  coco    17264 non-null  Float64
# dtypes: Float64(11)
# memory usage: 1.8 MB
# None
#
# Missing Values:
#  temp        0
# dwpt        0
# rhum        0
# prcp        0
# snow    17521
# wdir        0
# wspd        0
# wpgt    17521
# pres        0
# tsun    17521
# coco      257
# dtype: int64
#
# Statistical Summary:
#              temp       dwpt       rhum      prcp  snow        wdir      wspd  \
# count    17521.0    17521.0    17521.0   17521.0   0.0     17521.0   17521.0
# mean    9.403544   3.601261  69.644198  0.135643  <NA>  167.858398  5.713823
# std    10.926193  10.544417   17.67007  0.855117  <NA>   126.46487  5.344797
# min        -28.8      -35.7       12.0       0.0  <NA>         0.0       0.0
# 25%          0.8       -4.5       57.0       0.0  <NA>        20.0       3.0
# 50%          9.7        3.6       71.0       0.0  <NA>       180.0       5.0
# 75%         18.9       12.8       84.0       0.0  <NA>       270.0       8.0
# max         34.7       23.8      100.0      43.5  <NA>       360.0      67.0
#
#        wpgt         pres  tsun      coco
# count   0.0      17521.0   0.0   17264.0
# mean   <NA>  1015.057405  <NA>  3.640582
# std    <NA>     8.522696  <NA>  3.462871
# min    <NA>        980.4  <NA>       1.0
# 25%    <NA>       1009.6  <NA>       2.0
# 50%    <NA>       1015.1  <NA>       3.0
# 75%    <NA>       1020.5  <NA>       3.0
# max    <NA>       1049.8  <NA>      21.0
#
# First 5 Rows:
#                       temp  dwpt   rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2023-01-01 00:00:00   7.5   7.4   99.0   1.1  <NA>  180.0   4.0  <NA>  1006.7
# 2023-01-01 01:00:00   7.2   7.1   99.0   0.7  <NA>  190.0   4.0  <NA>  1005.9
# 2023-01-01 02:00:00   6.8   6.7   99.0   0.8  <NA>    0.0   0.0  <NA>  1005.0
# 2023-01-01 03:00:00   5.6   5.5   99.0   0.7  <NA>    0.0   0.0  <NA>  1004.1
# 2023-01-01 04:00:00   6.1   6.1  100.0   0.9  <NA>  360.0   6.0  <NA>  1004.0
#
#                      tsun  coco
# time
# 2023-01-01 00:00:00  <NA>   8.0
# 2023-01-01 01:00:00  <NA>   8.0
# 2023-01-01 02:00:00  <NA>   9.0
# 2023-01-01 03:00:00  <NA>   8.0
# 2023-01-01 04:00:00  <NA>   8.0

# %%
weather_df.reset_index(inplace=True)

# %%
#~ Dropping columns where all values are missing + dropping other not relevant predictors columns

weather_df.drop(columns=['snow','wpgt','tsun', 'pres', 'coco','wdir', 'rhum'], inplace=True)

# %%
#~ renaming weather_df's columns to a more descriptive name

weather_df.rename(columns={'temp':'temperature',
                           'dwpt':'dew_point',
                           'prcp':'precipitation',
                           'wspd':'wind_speed'
                           }, inplace=True)

# %%
#~ dropping dew_point due to high correlation with temperature

display(weather_df.corr(numeric_only=True))

weather_df.drop(columns=['dew_point'], inplace=True)
# Out:
#                temperature  dew_point  precipitation  wind_speed
# temperature       1.000000   0.923112       0.014496   -0.241845
# dew_point         0.923112   1.000000       0.088932   -0.253789
# precipitation     0.014496   0.088932       1.000000    0.029091
# wind_speed       -0.241845  -0.253789       0.029091    1.000000

# %%
explore_data(weather_df )
# Out:
# Dataframe Shape: (17521, 4)
#
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17521 entries, 0 to 17520
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           17521 non-null  datetime64[ns]
#  1   temperature    17521 non-null  Float64
#  2   precipitation  17521 non-null  Float64
#  3   wind_speed     17521 non-null  Float64
# dtypes: Float64(3), datetime64[ns](1)
# memory usage: 599.0 KB
# None
#
# Missing Values:
#  time             0
# temperature      0
# precipitation    0
# wind_speed       0
# dtype: int64
#
# Statistical Summary:
#                        time  temperature  precipitation  wind_speed
# count                17521      17521.0        17521.0     17521.0
# mean   2024-01-01 00:00:00     9.403544       0.135643    5.713823
# min    2023-01-01 00:00:00        -28.8            0.0         0.0
# 25%    2023-07-02 12:00:00          0.8            0.0         3.0
# 50%    2024-01-01 00:00:00          9.7            0.0         5.0
# 75%    2024-07-01 12:00:00         18.9            0.0         8.0
# max    2024-12-31 00:00:00         34.7           43.5        67.0
# std                    NaN    10.926193       0.855117    5.344797
#
# First 5 Rows:
#                   time  temperature  precipitation  wind_speed
# 0 2023-01-01 00:00:00          7.5            1.1         4.0
# 1 2023-01-01 01:00:00          7.2            0.7         4.0
# 2 2023-01-01 02:00:00          6.8            0.8         0.0
# 3 2023-01-01 03:00:00          5.6            0.7         0.0
# 4 2023-01-01 04:00:00          6.1            0.9         6.0

# %% [markdown]
# ## BIXI Trip Dataset

# %% [markdown]
# source: https://bixi.com/en/open-data/

# %%
explore_data(bixi_trip_df)
# Out:
# Dataframe Shape: (25066166, 10)
#
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25066166 entries, 0 to 25066165
# Data columns (total 10 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   STARTSTATIONNAME            object
#  1   STARTSTATIONARRONDISSEMENT  object
#  2   STARTSTATIONLATITUDE        float64
#  3   STARTSTATIONLONGITUDE       float64
#  4   ENDSTATIONNAME              object
#  5   ENDSTATIONARRONDISSEMENT    object
#  6   ENDSTATIONLATITUDE          float64
#  7   ENDSTATIONLONGITUDE         float64
#  8   STARTTIMEMS                 int64
#  9   ENDTIMEMS                   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.9+ GB
# None
#
# Missing Values:
#  STARTSTATIONNAME                5245
# STARTSTATIONARRONDISSEMENT      5442
# STARTSTATIONLATITUDE            5245
# STARTSTATIONLONGITUDE           5245
# ENDSTATIONNAME                139918
# ENDSTATIONARRONDISSEMENT      141815
# ENDSTATIONLATITUDE            139918
# ENDSTATIONLONGITUDE           139918
# STARTTIMEMS                        0
# ENDTIMEMS                     131923
# dtype: int64
#
# Statistical Summary:
#         STARTSTATIONLATITUDE  STARTSTATIONLONGITUDE  ENDSTATIONLATITUDE  \
# count          2.506092e+07           2.506092e+07        2.492625e+07
# mean           4.543292e+01          -7.344890e+01        4.541857e+01
# std            1.990640e+00           3.105848e+00        2.143849e+00
# min           -1.000000e+00          -7.375823e+01       -1.000000e+00
# 25%            4.550367e+01          -7.359361e+01        4.550229e+01
# 50%            4.552063e+01          -7.357700e+01        4.551990e+01
# 75%            4.553341e+01          -7.356629e+01        4.553335e+01
# max            4.570235e+01           0.000000e+00        4.570235e+01
#
#        ENDSTATIONLONGITUDE   STARTTIMEMS     ENDTIMEMS
# count         2.492625e+07  2.506617e+07  2.493424e+07
# mean         -7.342622e+01  1.707618e+12  1.707617e+12
# std           3.345162e+00  1.659396e+10  1.659383e+10
# min          -7.375823e+01  1.681314e+12  1.681314e+12
# 25%          -7.359235e+01  1.691543e+12  1.691544e+12
# 50%          -7.357591e+01  1.713973e+12  1.713960e+12
# 75%          -7.356391e+01  1.722903e+12  1.722903e+12
# max           0.000000e+00  1.735708e+12  1.736803e+12
#
# First 5 Rows:
#                                   STARTSTATIONNAME STARTSTATIONARRONDISSEMENT  \
# 0  Métro Mont-Royal (Utilités publiques / Rivard)      Le Plateau-Mont-Royal
# 1                             Rielle / Wellington                     Verdun
# 2                        Ste-Catherine / Drummond                Ville-Marie
# 3                           Boyer / du Mont-Royal      Le Plateau-Mont-Royal
# 4                                 Clark / Ontario                Ville-Marie
#
#    STARTSTATIONLATITUDE  STARTSTATIONLONGITUDE                ENDSTATIONNAME  \
# 0             45.524236             -73.581552           Chabot / Mont-Royal
# 1             45.460156             -73.567001           St-Jacques / McGill
# 2             45.498588             -73.574278                 Peel / Ottawa
# 3             45.527432             -73.579917  de l'Hôtel-de-Ville / Rachel
# 4             45.510625             -73.566903                 Wolfe / Robin
#
#   ENDSTATIONARRONDISSEMENT  ENDSTATIONLATITUDE  ENDSTATIONLONGITUDE  \
# 0    Le Plateau-Mont-Royal           45.534134           -73.573524
# 1              Ville-Marie           45.501441           -73.560144
# 2             Le Sud-Ouest           45.494200           -73.559985
# 3    Le Plateau-Mont-Royal           45.519897           -73.580106
# 4              Ville-Marie           45.519581           -73.560116
#
#      STARTTIMEMS     ENDTIMEMS
# 0  1698266696468  1.698267e+12
# 1  1698270535502  1.698272e+12
# 2  1698285705974  1.698286e+12
# 3  1698269489932  1.698270e+12
# 4  1698270006571  1.698270e+12

# %%
#~ standardizing columnsNames of bixi_trip_df

bixi_trip_df.columns = (bixi_trip_df.columns              
              .str.normalize('NFKD')                    
              .str.encode('ascii','ignore').str.decode('ascii')
              .str.strip()
              .str.lower()
              .str.replace(r'[^a-z0-9]+', '_', regex=True)  
              .str.replace(r'_+', '_', regex=True)          
              .str.strip('_'))

# %% [markdown]
# it seems that a majority of the null values are missing the endstation name and therefore has no endtime. We will assume that this is error in data capture
#
# We will drop all rows that has null values

# %%
bixi_trip_df.dropna(inplace=True)

# %% [markdown]
# creating a new column by transforming the startimems and endtimems  (these columns are in UNIX format)
# into datetime formatted as YYYY-MM-DD HH-mm-ss

# %%
bixi_trip_df['starttime'] = (
    pd.to_datetime(bixi_trip_df["starttimems"], unit='ms', utc=True)
      .dt.floor("s")                           #~ the data showed time zone in ISO-8601 format, I stopped at seconds
      .dt.tz_convert("America/Toronto")
      .dt.tz_localize(None)        
)


bixi_trip_df['endtime'] = (
    pd.to_datetime(bixi_trip_df["endtimems"], unit='ms', utc=True)
      .dt.floor("s")                           
      .dt.tz_convert("America/Toronto")
      .dt.tz_localize(None)       
)

bixi_trip_df.drop(columns=['starttimems', 'endtimems'],inplace=True) #~ dropping the initial unix time columns

# %%
#~ adding column to bring out the hour of the day, the day of week, day of month, and month of the year for starting time and endtime

#~Hour of day (0–23)

bixi_trip_df["start_hour"] = bixi_trip_df["starttime"].dt.hour
bixi_trip_df["end_hour"]   = bixi_trip_df["endtime"].dt.hour

#~Day of week (1–7, Monday=1, Sunday=7)

bixi_trip_df["start_day"] = bixi_trip_df["starttime"].dt.dayofweek + 1
bixi_trip_df["end_day"]   = bixi_trip_df["endtime"].dt.dayofweek + 1

#~Day of month (1–31)
bixi_trip_df["start_dayofmonth"] = bixi_trip_df["starttime"].dt.day
bixi_trip_df["end_dayofmonth"]   = bixi_trip_df["endtime"].dt.day

#~Month of year (1–12)

bixi_trip_df["start_month"] = bixi_trip_df["starttime"].dt.month
bixi_trip_df["end_month"]   = bixi_trip_df["endtime"].dt.month

# %%
display(bixi_trip_df.head())
# Out:
#                                  startstationname startstationarrondissement  \
# 0  Métro Mont-Royal (Utilités publiques / Rivard)      Le Plateau-Mont-Royal
# 1                             Rielle / Wellington                     Verdun
# 2                        Ste-Catherine / Drummond                Ville-Marie
# 3                           Boyer / du Mont-Royal      Le Plateau-Mont-Royal
# 4                                 Clark / Ontario                Ville-Marie
#
#    startstationlatitude  startstationlongitude                endstationname  \
# 0             45.524236             -73.581552           Chabot / Mont-Royal
# 1             45.460156             -73.567001           St-Jacques / McGill
# 2             45.498588             -73.574278                 Peel / Ottawa
# 3             45.527432             -73.579917  de l'Hôtel-de-Ville / Rachel
# 4             45.510625             -73.566903                 Wolfe / Robin
#
#   endstationarrondissement  endstationlatitude  endstationlongitude  \
# 0    Le Plateau-Mont-Royal           45.534134           -73.573524
# 1              Ville-Marie           45.501441           -73.560144
# 2             Le Sud-Ouest           45.494200           -73.559985
# 3    Le Plateau-Mont-Royal           45.519897           -73.580106
# 4              Ville-Marie           45.519581           -73.560116
#
#             starttime             endtime  start_hour  end_hour  start_day  \
# 0 2023-10-25 16:44:56 2023-10-25 16:51:32          16        16          3
# 1 2023-10-25 17:48:55 2023-10-25 18:12:47          17        18          3
# 2 2023-10-25 22:01:45 2023-10-25 22:06:32          22        22          3
# 3 2023-10-25 17:31:29 2023-10-25 17:36:54          17        17          3
# 4 2023-10-25 17:40:06 2023-10-25 17:47:20          17        17          3
#
#    end_day  start_dayofmonth  end_dayofmonth  start_month  end_month
# 0        3                25              25           10         10
# 1        3                25              25           10         10
# 2        3                25              25           10         10
# 3        3                25              25           10         10
# 4        3                25              25           10         10

# %% [markdown]
# # Parquet Dataframes

# %%
#~ parquet saving cleaned dataframes

weather_df.to_parquet(PROCESSED_DIR/'weather_data.parquet', index=False)

bixi_trip_df.to_parquet(PROCESSED_DIR/'bixi_trip_data.parquet', index=False)

stations_status_df.to_parquet(PROCESSED_DIR/'bixi_stations_data.parquet', index=False)
